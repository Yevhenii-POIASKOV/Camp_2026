# %% [markdown]
# # Домашнє завдання: Перший Data Pipeline в AWS

# %% [markdown]
# ## Скріншот 1: Активний аларм у CloudWatch на суму $1.

# %% [markdown]
# <img src="./screenshots/Billing.png">

# %% [markdown]
# ## Скріншот 2: Скріншот завантаженого файлу у S3 Бакет.

# %% [markdown]
# <img src="./screenshots/Bucket.png">

# %% [markdown]
# ## Скріншот 3: Список користувачів у IAM (має бути видно вашого адміна).

# %% [markdown]
# <img src="./screenshots/User.png">

# %% [markdown]
# ## Скріншот 4: Таблиця у Glue Catalog, яку створив кравлер (має бути видноструктуру колонок та типів даних).

# %% [markdown]
# <img src="./screenshots/schema.png">

# %% [markdown]
# ## Скріншот 5: Вікно результатів Athena з даними, які ви дістали з файлу.

# %% [markdown]
# <img src="./screenshots/Table.png">
